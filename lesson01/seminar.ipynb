# %% [markdown]
# # Семинар 01. Обзор Python
#
# Переводим знакомые алгоритмические конструкции на Python и оформляем решения как небольшие функции.

# %% [markdown]
# ## Цели
#
# - быстро освоиться с выражениями и truthiness Python;
# - записывать условия с правильными границами;
# - использовать `for`, `range` и накопитель;
# - применять `while` к процессу с неизвестным числом шагов;
# - оформлять правило как функцию с `return`;
# - читать простые сообщения об ошибках.

# %% [markdown]
# ## Перед началом
#
# Выполняйте ячейки сверху вниз. В ячейках с `TODO` сначала сформулируйте решение словами, затем исправьте код и выполните проверки `assert`. Инструкция `assert condition` завершает выполнение с `AssertionError`, если условие ложно.

# %% [markdown]
# ## Задание 1. Тип имеет значение
#
# Предскажите результат каждого выражения. Исправьте последнее выражение так, чтобы оно вычисляло число `120`, а не строку.

# %%
print(10 + 20)
print("10" + "20")
print("ha" * 3)

value = "100"
# TODO: преобразуйте value перед сложением.
result = value + "20"
assert result == 120

# %% [markdown]
# ## Задание 2. Экономика одной продажи
#
# Вычислите выручку, общие переменные затраты и прибыль. Затем выведите результат строкой `profit: 4400.00`.

# %%
price = 850
unit_cost = 410
quantity = 10

# TODO: замените None арифметическими выражениями.
revenue = None
total_cost = None
profit = None
message = None

assert revenue == 8500
assert total_cost == 4100
assert profit == 4400
assert message == "profit: 4400.00"
print(message)

# %% [markdown]
# ## Задание 3. Цикл и накопители
#
# Для чисел от 1 до `limit` включительно посчитайте сумму чисел и количество чисел, кратных трём. Используйте один цикл `for`.

# %%
limit = 10
total = 0
divisible_by_three = 0

# TODO: for number in range(...).

assert total == 55
assert divisible_by_three == 3

# %% [markdown]
# ## Задание 4. Цикл с неизвестным числом шагов
#
# Капитал растёт на 10% за период. С помощью `while` определите, сколько начислений потребуется для достижения цели.

# %%
capital = 100.0
target = 130.0
rate = 0.10
periods = 0

# TODO: while capital < target.

assert periods == 3
assert capital >= target

# %% [markdown]
# ## Задание 5. Три результата
#
# Присвойте переменной `status` значение `profit`, `loss` или `break-even`. После первого решения самостоятельно проверьте ещё два случая, меняя входные значения.

# %%
revenue = 500
expenses = 500

# TODO: напишите if/elif/else и определите status.
status = None

assert status == "break-even"

# %% [markdown]
# ## Задание 6. Комиссия как функция
#
# Оформите правило комиссии как функцию: 1% суммы, но не меньше 50 и не больше 500 рублей. Функция должна возвращать значение и ничего не печатать.

# %%
def transfer_fee(amount: float) -> float:
    # TODO: вычислите процент, примените границы и верните результат.
    return 0.0


assert transfer_fee(1_000) == 50
assert transfer_fee(20_000) == 200
assert transfer_fee(80_000) == 500

# %% [markdown]
# ## Задание 7. Функция решения по заявке
#
# Заявка одобряется, если возраст от 21 до 65 лет включительно, доход не меньше 50 000, платежи не превышают 40% дохода и просрочки нет. Верните логический результат из функции.

# %%
def is_approved(
    age: int, income: int, payments: int, has_overdue: bool
) -> bool:
    # TODO: разбейте правило на именованные условия и верните результат.
    return False


assert is_approved(30, 90_000, 30_000, False) == True
assert is_approved(20, 90_000, 30_000, False) == False
assert is_approved(30, 90_000, 40_000, False) == False

# %% [markdown]
# ## Задание 8. Найдите ошибки
#
# В каждом фрагменте есть одна ошибка. Назовите её тип до исправления.
#
# ```python
# income = input()
# print(income * 12)
# ```
#
# ```python
# if income >= 50000
#     print("approved")
# ```
#
# ```python
# status = "profit"
# if status = "profit":
#     print(status)
# ```
#
# Первый фрагмент синтаксически допустим, но повторяет строку вместо умножения числа. Два остальных содержат синтаксические ошибки.

# %% [markdown]
# ## Проверка границ
#
# Для условия `21 <= age <= 65` недостаточно проверить возраст 30. Минимальный набор включает 20, 21, 65 и 66. Такой подход понадобится во всех последующих заданиях: проверяйте обычный случай, границы и значения непосредственно за ними.

# %% [markdown]
# ## Самопроверка
#
# 1. Почему `"10" + "20"` не равно числу 30?
# 2. Как записать включительный диапазон от 21 до 65?
# 3. Что накапливается в цикле задания 3?
# 4. Почему цикл задания 4 завершается?
# 5. Чем `return` отличается от `print`?
# 6. Что произойдёт, если заменить `and` на `or` в условиях одобрения заявки?
# 7. Какие значения нужно проверить около каждой границы?

# %% [markdown]
# ## Итоги
#
# Мы перевели базовые конструкции императивного программирования на Python: выражения, truthiness, ветвления, `for`, `while` и функции с `return`.
#
# Для самостоятельной работы решите [3 задачи Easy и 2 задачи Medium](tasks.md). На занятии 2 появятся последовательности, структурное сопоставление и работа с файлами.
